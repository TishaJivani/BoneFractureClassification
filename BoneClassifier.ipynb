# %%
# !pip install keras
# !pip install tensorflow
# Out:
# Requirement already satisfied: keras in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (2.14.0)
# Requirement already satisfied: tensorflow in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (2.14.1)
# Requirement already satisfied: tensorflow-macos==2.14.1 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from tensorflow) (2.14.1)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from tensorflow-macos==2.14.1->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from tensorflow-macos==2.14.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from tensorflow-macos==2.14.1->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from tensorflow-macos==2.14.1->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from tensorflow-macos==2.14.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from tensorflow-macos==2.14.1->tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from tensorflow-macos==2.14.1->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes==0.2.0 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from tensorflow-macos==2.14.1->tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from tensorflow-macos==2.14.1->tensorflow) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from tensorflow-macos==2.14.1->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from tensorflow-macos==2.14.1->tensorflow) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from tensorflow-macos==2.14.1->tensorflow) (4.25.3)
# Requirement already satisfied: setuptools in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from tensorflow-macos==2.14.1->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from tensorflow-macos==2.14.1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from tensorflow-macos==2.14.1->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from tensorflow-macos==2.14.1->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from tensorflow-macos==2.14.1->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from tensorflow-macos==2.14.1->tensorflow) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from tensorflow-macos==2.14.1->tensorflow) (1.62.1)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from tensorflow-macos==2.14.1->tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from tensorflow-macos==2.14.1->tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from tensorflow-macos==2.14.1->tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.14.1->tensorflow) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.1->tensorflow) (2.31.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.1->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.1->tensorflow) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.1->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.1->tensorflow) (3.0.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.1->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.1->tensorflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.1->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.1->tensorflow) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.1->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.1->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.1->tensorflow) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.1->tensorflow) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.1->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.1->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/tisha/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.1->tensorflow) (3.2.2)

# %%
# !pip3 install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (24.1)
# Collecting pip
#   Using cached pip-24.2-py3-none-any.whl.metadata (3.6 kB)
# Using cached pip-24.2-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1
#     Uninstalling pip-24.1:
#       Successfully uninstalled pip-24.1
# Successfully installed pip-24.2

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Input
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
from PIL import ImageFile

# %%
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
# Data Augmentation
train_datagen = ImageDataGenerator(rescale=1./255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

# Ensure the directory paths are correct
training_set = train_datagen.flow_from_directory('/Users/tisha/Downloads/Bone-Fracture-Classification/Bone_Dataset/train',
                                                 target_size=(64, 64),
                                                 batch_size=32,
                                                 class_mode='binary')

test_set = test_datagen.flow_from_directory('/Users/tisha/Downloads/Bone-Fracture-Classification/Bone_Dataset/test',
                                            target_size=(64, 64),
                                            batch_size=32,
                                            class_mode='binary')
# Out:
# Found 9246 images belonging to 2 classes.
# Found 506 images belonging to 2 classes.

# %%
# Function to preprocess the uploaded image and make predictions
def predict_image(img_path, model):
    img = image.load_img(img_path, target_size=(64, 64))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0  # rescaling
    result = model.predict(img_array)
    return result[0][0]

# %%
# Initialising the CNN
classifier = Sequential()

# Adding the Input layer
classifier.add(Input(shape=(64, 64, 3)))

# Step 1 - Convolution
classifier.add(Conv2D(32, (3, 3), activation='relu'))

# Step 2 - Pooling
classifier.add(MaxPooling2D(pool_size=(2, 2)))

# Adding a second convolutional layer
classifier.add(Conv2D(32, (3, 3), activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2, 2)))

# Step 3 - Flattening
classifier.add(Flatten())

# Step 4 - Full connection
classifier.add(Dense(units=64, activation='relu'))
classifier.add(Dense(units=1, activation='sigmoid'))

# Compiling the CNN
classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Training the CNN
history = classifier.fit(training_set,
                         epochs=5,
                         validation_data=test_set)
# Out:
# Epoch 1/5
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 34s 114ms/step - accuracy: 0.6662 - loss: 0.5921 - val_accuracy: 0.8202 - val_loss: 0.4112
# Epoch 2/5
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 31s 107ms/step - accuracy: 0.8580 - loss: 0.3377 - val_accuracy: 0.8636 - val_loss: 0.3731
# Epoch 3/5
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 32s 108ms/step - accuracy: 0.9147 - loss: 0.2228 - val_accuracy: 0.8478 - val_loss: 0.5357
# Epoch 4/5
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 31s 105ms/step - accuracy: 0.9429 - loss: 0.1579 - val_accuracy: 0.9071 - val_loss: 0.2577
# Epoch 5/5
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 31s 107ms/step - accuracy: 0.9591 - loss: 0.1150 - val_accuracy: 0.9447 - val_loss: 0.1977

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %%
# Create a Sequential model
model = Sequential()

# %%
# Add convolutional and pooling layers
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
# Add dense layers
model.add(Dense(512, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# Compile the model
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
# Save the model
model.save('model.h5')

print("Model saved successfully!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully!

# %%
# Extracting values from the history object
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(len(history.history['loss']))

# Plotting training and validation accuracy
plt.figure(figsize=(15, 10))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

# Plotting training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')

plt.show()

# %%
from PIL import Image
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image

# Path to the uploaded image
uploaded_image_path = '/Users/tisha/Downloads/Bone_Dataset/Bone_Fracture_Binary_Classification/Bone_Fracture_Binary_Classification/train/not fractured/1-rotated2-rotated1-rotated2.jpg'

# Predicting the class of the uploaded image
prediction = predict_image(uploaded_image_path, classifier)

# Open and resize the image
with Image.open(uploaded_image_path) as img:
    img_resized = img.resize((256, 256))

# Display the resized image and the prediction result
plt.imshow(img_resized)
plt.axis('off')
if prediction > 0.5:
    plt.title(' No Fractures Here, Clear Bones!🦴')
else:
    plt.title('Fracture Detected, Caution Advised! 🚨')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# /Users/tisha/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 129460 (\N{BONE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
